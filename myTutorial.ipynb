# %%
import pandas as pd

#DataFrame is the key data structure 
df = pd.DataFrame([[1,2,3], [4,5,6], [7,8,9]], columns=["A", "B" , "C"] , index= ["D", "E", "F"])

# %%
df.head()
# Out:
#    A  B  C
# D  1  2  3
# E  4  5  6
# F  7  8  9
